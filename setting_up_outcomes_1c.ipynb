// %%
cd
// Out:
// D:\Box Sync\Policy Evaluation\dofiles

// %%
use "..\working_data\collision_signal_intersection.dta",clear

// %%
gen intersection_id = nearest_sigInt

// %%
codebook intersection_id
// Out:
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// intersection_id                                                                                                                                                                                                                                     (unlabeled)
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//
//                   type:  numeric (float)
//
//                  range:  [1,13214]                    units:  1
//          unique values:  13,116                   missing .:  0/1,147,839
//
//                   mean:    6513.4
//               std. dev:   3979.88
//
//            percentiles:        10%       25%       50%       75%       90%
//                                981      3009      6437     10260     11828

// %%
// Determine if collisions that are close to an intersection
sum distance_to_sigInt, detail
// Out:
//                      distance_to_sigInt
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%            2              0
//  5%            2              0
// 10%            2              0       Obs           1,147,839
// 25%            3              0       Sum of Wgt.   1,147,839
//
// 50%           10                      Mean           208.3536
//                         Largest       Std. Dev.      375.8735
// 75%          279           7498
// 90%          615           7500       Variance       141280.9
// 95%          853           7500       Skewness       4.267881
// 99%         1632           7685       Kurtosis       35.85233

// %%
sum distance_to_sigInt if distance_to_sigInt < r(p75), detail
// Out:
//                      distance_to_sigInt
// -------------------------------------------------------------
//       Percentiles      Smallest
//  1%            1              0
//  5%            2              0
// 10%            2              0       Obs             859,866
// 25%            3              0       Sum of Wgt.     859,866
//
// 50%            3                      Mean           51.85574
//                         Largest       Std. Dev.      86.39933
// 75%           65            278
// 90%          227            278       Variance       7464.844
// 95%          259            278       Skewness       1.550851
// 99%          273            278       Kurtosis       3.837138

// %%
gen intersection = distance_to_sigInt < 10

// %%
tab intersection
// Out:
// intersectio |
//           n |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |    576,297       50.21       50.21
//           1 |    571,542       49.79      100.00
// ------------+-----------------------------------
//       Total |  1,147,839      100.00

// %%
keep if intersection == 1
// Out:
// (576,297 observations deleted)

// %%
codebook date
// Out:
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// date                                                                                                                                                                                                                                                (unlabeled)
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//
//                   type:  string (str10)
//
//          unique values:  2,277                    missing "":  0/571,542
//
//               examples:  "2013-08-22"
//                          "2014-10-11"
//                          "2015-11-22"
//                          "2017-05-18"

// %%
sum date, format
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//         date |          0

// %%
gen date2 = date(date, "YMD"),after(date)
format date2 %td
drop date
rename date2 date

// %%
%browse
// Out:
// <div>
// <style scoped>
//     .dataframe tbody tr th:only-of-type {
//         vertical-align: middle;
//     }
//
//     .dataframe tbody tr th {
//         vertical-align: top;
//     }
//
//     .dataframe thead th {
//         text-align: right;
//     }
// </style>
// <table border="1" class="dataframe">
//   <thead>
//     <tr style="text-align: right;">
//       <th></th>
//       <th>index</th>
//       <th>uniquekey</th>
//       <th>year</th>
//       <th>date</th>
//       <th>time</th>
//       <th>latenight</th>
//       <th>borough</th>
//       <th>zipcode</th>
//       <th>latitude</th>
//       <th>longitude</th>
//       <th>mi_latlong</th>
//       <th>imput_latlong</th>
//       <th>mi_latlong2</th>
//       <th>location</th>
//       <th>onstreetname</th>
//       <th>crossstreetname</th>
//       <th>offstreetname</th>
//       <th>personsinjured</th>
//       <th>personskilled</th>
//       <th>pedestriansinjured</th>
//       <th>pedestrianskilled</th>
//       <th>cyclistinjured</th>
//       <th>cyclistkilled</th>
//       <th>motoristinjured</th>
//       <th>motoristkilled</th>
//       <th>contributingfactorvehicle1</th>
//       <th>contributingfactorvehicle2</th>
//       <th>contributingfactorvehicle3</th>
//       <th>contributingfactorvehicle4</th>
td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>Passenger Distraction</td>
//       <td>Unspecified</td>
//       <td>.</td>
//       <td>.</td>
//       <td>.</td>
//       <td>PASSENGER VEHICLE</td>
//       <td>TAXI</td>
//       <td>.</td>
//       <td>.</td>
//       <td>.</td>
//       <td>0</td>
//       <td>1</td>
//       <td>0</td>
//       <td>.</td>
//       <td>POINT (984455.0188453833 215988.0937347476)</td>
//       <td>2</td>
//       <td>1138</td>
//       <td>1138</td>
//       <td>1</td>
//     </tr>
//     <tr>
//       <th>5</th>
//       <td>500</td>
//       <td>3313812</td>
//       <td>2015</td>
//       <td>11oct2015</td>
//       <td>1960-01-01 17:35:00</td>
//       <td>0</td>
//       <td>.</td>
//       <td>.</td>
//       <td>40.71512</td>
//       <td>-73.77357</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>(40.7151196, -73.7735714)</td>
//       <td>.</td>
//       <td>.</td>
//       <td>GAS SATION 187-39 HILLSIDE AVENUE</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>Prescription Medication</td>
//       <td>Unspecified</td>
//       <td>.</td>
//       <td>.</td>
//       <td>.</td>
//       <td>SPORT UTILITY / STATION WAGON</td>
//       <td>SPORT UTILITY / STATION WAGON</td>
//       <td>.</td>
//       <td>.</td>
//       <td>.</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>.</td>
//       <td>POINT (1047019.051383508 199894.5542110965)</td>
//       <td>2</td>
//       <td>10023</td>
//       <td>10023</td>
//       <td>1</td>
//     </tr>
//     <tr>
//       <th>6</th>
//       <td>567</td>
//       <td>3718418</td>
//       <td>2017</td>
//       <td>24jul2017</td>
//       <td>1960-01-01 14:20:00</td>
//       <td>0</td>
//       <td>.</td>
//       <td>.</td>
//       <td>40.66416</td>
//       <td>-73.99052</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>(40.66416, -73.990524)</td>
//       <td>.</td>
//       <td>.</td>
//       <td>PROSPECT AVENUE</td>
//       <td>2</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>2</td>
//       <td>0</td>
//       <td>Lost Consciousness</td>
//       <td>Unspecified</td>
//       <td>Unspecified</td>
//       <td>.</td>
//       <td>.</td>
//       <td>PASSENGER VEHICLE</td>
//       <td>PASSENGER VEHICLE</td>
//       <td>SPORT UTILITY / STATION WAGON</td>
//       <td>.</td>
//       <td>.</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>.</td>
//       <td>POINT (986878.8445717299 181248.5452909043)</td>
//       <td>3</td>
//       <td>5483</td>
//       <td>5483</td>
//       <td>1</td>
//     </tr>
//     <tr>
//       <th>7</th>
//       <td>580</td>
//       <td>3786392</td>
//       <td>2017</td>
//       <td>08nov2017</td>
//       <td>1960-01-01 19:00:00</td>
//       <td>0</td>
//       <td>.</td>
//       <td>.</td>
//       <td>40.57577</td>
//       <td>-74.16981</td>
//       <td>0</td>
//       <td>0</td>
//       <td>0</td>
//       <td>(40.57577, -74.16981)</td>
//       <td>.</td>
//       <td>.</td>
//       <td>2873      RICHMON

// %%
gen month = month(date)
gen collision_count = 1

// %%
gen latenight_collision_count = latenight*collision_count
gen latenight_personsinjured = latenight*personsinjured
gen latenight_personskilled = latenight*personskilled
gen latenight_pedestriansinjured = latenight*pedestriansinjured
gen latenight_pedestrianskilled = latenight*pedestrianskilled
gen latenight_cyclistinjured = latenight*cyclistinjured
gen latenight_cyclistkilled = latenight*cyclistkilled
gen latenight_motoristinjured = latenight*motoristinjured
gen latenight_motoristkilled = latenight*motoristkilled

gen day = (latenight == 0)

gen day_collision_count = day*collision_count
gen day_personsinjured = day*personsinjured
gen day_personskilled = day*personskilled
gen day_pedestriansinjured = day*pedestriansinjured
gen day_pedestrianskilled = day*pedestrianskilled
gen day_cyclistinjured = day*cyclistinjured
gen day_cyclistkilled = day*cyclistkilled
gen day_motoristinjured = day*motoristinjured
gen day_motoristkilled = day*motoristkilled

// %%
global counts collision_count latenight_collision_count day_collision_count
global all_outcome personsinjured personskilled pedestriansinjured pedestrianskilled cyclistinjured cyclistkilled motoristinjured motoristkilled 
global late_outcome latenight_personsinjured latenight_personskilled latenight_pedestriansinjured latenight_pedestrianskilled latenight_cyclistinjured latenight_cyclistkilled latenight_motoristinjured latenight_motoristkilled
global day_outcome day_personsinjured day_personskilled day_pedestriansinjured day_pedestrianskilled day_cyclistinjured day_cyclistkilled day_motoristinjured day_motoristkilled

collapse ///
(sum) "$counts $all_outcome $late_outcome $day_outcome" ///
 , by(intersection_id month year )

save "..\working_data\collision_monthly.dta",replace
// Out:
// file ..\working_data\collision_monthly.dta saved

// %%
sum intersection_id
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// intersecti~d |    338,263    5852.727    3803.482          1      13214

// %%
duplicates report month year intersection_id
// Out:
// Duplicates in terms of month year intersection_id
//
// --------------------------------------
//    copies | observations       surplus
// ----------+---------------------------
//         1 |       338263             0
// --------------------------------------

// %%
des
// Out:
// Contains data from ..\working_data\collision_monthly.dta
//   obs:       338,263
//  vars:            30                          15 Nov 2018 16:08
//  size:    77,123,964
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// year            float   %9.0g
// intersection_id float   %9.0g
// month           float   %9.0g
// collision_count double  %9.0g                 (sum) collision_count
// latenight_col~t double  %9.0g                 (sum) latenight_collision_count
// day_collision~t double  %9.0g                 (sum) day_collision_count
// personsinjured  double  %10.0g                (sum) personsinjured
// personskilled   double  %10.0g                (sum) personskilled
// pedestriansin~d double  %10.0g                (sum) pedestriansinjured
// pedestrianski~d double  %10.0g                (sum) pedestrianskilled
// cyclistinjured  double  %10.0g                (sum) cyclistinjured
// cyclistkilled   double  %10.0g                (sum) cyclistkilled
// motoristinjured double  %10.0g                (sum) motoristinjured
// motoristkilled  double  %10.0g                (sum) motoristkilled
// late~onsinjured double  %9.0g                 (sum) latenight_personsinjured
// laten~onskilled double  %9.0g                 (sum) latenight_personskilled
// late~ansinjured double  %9.0g                 (sum) latenight_pedestriansinjured
// laten~anskilled double  %9.0g                 (sum) latenight_pedestrianskilled
// latenight_c~red double  %9.0g                 (sum) latenight_cyclistinjured
// latenight_c~led double  %9.0g                 (sum) latenight_cyclistkilled
// latenight_m~red double  %9.0g                 (sum) latenight_motoristinjured
// latenight_m~led double  %9.0g                 (sum) latenight_motoristkilled
// day_personsin~d double  %9.0g                 (sum) day_personsinjured
// day_personski~d double  %9.0g                 (sum) day_personskilled
// day_pedestr~red double  %9.0g                 (sum) day_pedestriansinjured
// day_pedestr~led double  %9.0g                 (sum) day_pedestrianskilled
// day_cyclistin~d double  %9.0g                 (sum) day_cyclistinjured
// day_cyclistki~d double  %9.0g                 (sum) day_cyclistkilled
// day_motoristi~d double  %9.0g                 (sum) day_motoristinjured
// day_motoristk~d double  %9.0g                 (sum) day_motoristkilled
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// Sorted by: intersection_id  month  year

// %%
codebook intersection_id
// Out:
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
// intersection_id                                                                                                                                                                                                                                     (unlabeled)
// ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
//
//                   type:  numeric (float)
//
//                  range:  [1,13214]                    units:  1
//          unique values:  11,554                   missing .:  0/338,263
//
//                   mean:   5852.73
//               std. dev:   3803.48
//
//            percentiles:        10%       25%       50%       75%       90%
//                                908      2258      5783      9242     11202
